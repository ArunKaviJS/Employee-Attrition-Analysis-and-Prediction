# %% [markdown]
# # JOBSATISFACTION

# %%
import pandas as pd

# %%
df=pd.read_csv(r'..\Data\Employee-Attrition - Employee-Attrition (1).csv')

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %% [markdown]
# # with target we selected the features
# WorkLifeBalance, YearsInCurrentRole, YearsAtCompany, YearsWithCurrManager , TotalWorkingYears, RelationshipSatisfaction etc...

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
feature_num=df[['Age','Attrition','DistanceFromHome','Education','EducationField','EnvironmentSatisfaction','JobInvolvement','MonthlyIncome','MonthlyRate','PercentSalaryHike','RelationshipSatisfaction','PerformanceRating','WorkLifeBalance','YearsInCurrentRole','YearsAtCompany','YearsSinceLastPromotion','YearsWithCurrManager']]

# %%
feature_num.columns
# Out:
# Index(['Age', 'Attrition', 'DistanceFromHome', 'Education', 'EducationField',
#        'EnvironmentSatisfaction', 'JobInvolvement', 'MonthlyIncome',
#        'MonthlyRate', 'PercentSalaryHike', 'RelationshipSatisfaction',
#        'PerformanceRating', 'WorkLifeBalance', 'YearsInCurrentRole',
#        'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# cat_num=Attrition,BusinessTravel,department,educationfield,gender,jobrole,maritalstatus,overtime

# %%
df['PercentSalaryHike'].value_counts()
# Out:
# PercentSalaryHike
# 11    210
# 13    209
# 14    201
# 12    198
# 15    101
# 18     89
# 17     82
# 16     78
# 19     76
# 22     56
# 20     55
# 21     48
# 23     28
# 24     21
# 25     18
# Name: count, dtype: int64

# %% [markdown]
# # ENCODING

# %%
from sklearn.preprocessing import OneHotEncoder
ohe_for_job_sat=OneHotEncoder(sparse_output=False)

# %%
one_hot_job_satisfy=ohe_for_job_sat.fit_transform(df[['BusinessTravel','Department','EducationField','Gender','JobRole','MaritalStatus']])

# %%
import joblib

# %%
joblib.dump(ohe_for_job_sat,r'..\Models\onehotforjobsat.pkl')
# Out:
# ['..\\Models\\onehotforjobsat.pkl']

# %%
encoded_df=pd.DataFrame(one_hot_job_satisfy,columns=ohe_for_job_sat.get_feature_names_out(['BusinessTravel','Department','EducationField','Gender','JobRole','MaritalStatus'])).astype(int)
encoded_df
# Out:
#       BusinessTravel_Non-Travel  BusinessTravel_Travel_Frequently  \
# 0                             0                                 0
# 1                             0                                 1
# 2                             0                                 0
# 3                             0                                 1
# 4                             0                                 0
# ...                         ...                               ...
# 1465                          0                                 1
# 1466                          0                                 0
# 1467                          0                                 0
# 1468                          0                                 1
# 1469                          0                                 0
#
#       BusinessTravel_Travel_Rarely  Department_Human Resources  \
# 0                                1                           0
# ...

# %% [markdown]
# # LABEL ENCODER

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_for_job_sat=LabelEncoder()

# %%
label=['Attrition','OverTime']

# %%
df['OverTime'] = label_for_job_sat.fit_transform(df['OverTime'])
df['Attrition']=label_for_job_sat.fit_transform(df['Attrition'])

# %%
label_column=df[['OverTime','Attrition']]

# %%
joblib.dump(label_for_job_sat,r'..\Models\labelforjobsat.pkl')
# Out:
# ['..\\Models\\labelforjobsat.pkl']

# %%
feature=pd.concat([feature_num,encoded_df,df['OverTime'],df['Attrition']],axis=1)

# %%
feature.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 45 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Age                                1470 non-null   int64
#  1   Attrition                          1470 non-null   int64
#  2   DistanceFromHome                   1470 non-null   int64
#  3   Education                          1470 non-null   int64
#  4   EducationField                     1470 non-null   object
#  5   EnvironmentSatisfaction            1470 non-null   int64
#  6   JobInvolvement                     1470 non-null   int64
#  7   MonthlyIncome                      1470 non-null   int64
#  8   MonthlyRate                        1470 non-null   int64
#  9   PercentSalaryHike                  1470 non-null   int64
#  10  RelationshipSatisfaction           1470 non-null   int64
# ...

# %%
feature.drop(['EducationField'],axis=1,inplace=True)

# %%
feature.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 44 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Age                                1470 non-null   int64
#  1   Attrition                          1470 non-null   int64
#  2   DistanceFromHome                   1470 non-null   int64
#  3   Education                          1470 non-null   int64
#  4   EnvironmentSatisfaction            1470 non-null   int64
#  5   JobInvolvement                     1470 non-null   int64
#  6   MonthlyIncome                      1470 non-null   int64
#  7   MonthlyRate                        1470 non-null   int64
#  8   PercentSalaryHike                  1470 non-null   int64
#  9   RelationshipSatisfaction           1470 non-null   int64
#  10  PerformanceRating                  1470 non-null   int64
# ...

# %%
feature.to_csv(r'..\Data\feature0fJobsatis.csv')

# %%
target=df['JobSatisfaction']

# %%
target.to_csv(r'..\Data\targetofjobsatisfy.csv')

# %%
feature=pd.read_csv(r'..\Data\feature0fJobsatis.csv')
target=pd.read_csv(r'..\Data\targetofjobsatisfy.csv')

# %%
del feature['Unnamed: 0']
del target['Unnamed: 0']

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score,classification_report,confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
import xgboost as xgb

# %%
models={'Logisticregression':LogisticRegression(),'decisiontreeclassifier':DecisionTreeClassifier(),'randomforestclassifier':RandomForestClassifier(),'xgboost':xgb.XGBClassifier()}

# %%
def Modeltrain(x_train,x_test,y_train,y_test):
 for name,model in models.items():
     print(f'************************************{name}********************************************')
     model.fit(x_train,y_train)

     print(f'trained with : {name}')

     predict=model.predict(x_test)
     predict_train=model.predict(x_train)

     accuracy_test=accuracy_score(y_test,predict)
     print(f'accuracy_score_test : {accuracy_test}')
     accuracy_train=accuracy_score(y_train,predict_train,)
     print(f'accuracy_score_train:{accuracy_train}')
     print('-----------------------------------------------------------------------------------')
     precision=precision_score(y_test,predict, average='weighted')
     print(f'precision_score_test:{precision}')
     precision_train=precision_score(y_train,predict_train,average='weighted')
     print(f'precision_train:{precision_train}')
     print('-----------------------------------------------------------------------------------')

     recall=recall_score(y_test,predict,average='weighted')
     print(f'recall_test:{recall}')
     recall_train=recall_score(y_train,predict_train,average='weighted')
     print(f'recallscore_train:{recall_train}')
     print('-----------------------------------------------------------------------------------')

     f1=f1_score(y_test,predict,average='weighted')
     print(f'f1_score_test:{f1}')
     f1_train=f1_score(y_train,predict_train,average='weighted')
     print(f'f1score_train:{f1_train}')

     print('-----------------------------------------------------------------------------------')
     #roc=roc_auc_score(y_test,predict,multi_class='ovr')
     #print(f'roc_auc_score_test:{roc}')
     #roc_train=roc_auc_score(y_train,predict_train,multi_class='ovr')
     #print(f'roc_auc_score(:{roc_train}')

     print('-----------------------------------------------------------------------------------')

     cr=classification_report(y_test,predict)
     print(cr)

     cm=confusion_matrix(y_test,predict)
     #print(f'[TN  FP  \n FN TP]:\n{cm}')

# %%
feature_train,feature_test,target_train,target_test=train_test_split(feature,target)

# %%
Modeltrain(feature_train,feature_test,target_train,target_test)
# Out:
# ************************************Logisticregression********************************************
# trained with : Logisticregression
# accuracy_score_test : 0.31521739130434784
# accuracy_score_train:0.32304900181488205
# -----------------------------------------------------------------------------------
# precision_score_test:0.20100823634269954
# precision_train:0.19509633931721268
# -----------------------------------------------------------------------------------
# recall_test:0.31521739130434784
# recallscore_train:0.32304900181488205
# -----------------------------------------------------------------------------------
# f1_score_test:0.24527638256393736
# f1score_train:0.24320122104729316
# -----------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00        73
# ...

# %%
rfc=RandomForestClassifier()

# %%
rfc.fit(feature_train,target_train)
# Out:
# d:\Projects\Employee-Attrition-Analysis-and-Prediction\venv\Lib\site-packages\sklearn\base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestClassifier()

# %%
import numpy as np

# %%
ohe_for_job_sat=joblib.load(r'..\Models\onehotforjobsat.pkl')
label_for_job_sat=joblib.load(r'..\Models\labelforjobsat.pkl')

# %%
feature.columns
# Out:
# Index(['Age', 'Attrition', 'DistanceFromHome', 'Education',
#        'EnvironmentSatisfaction', 'JobInvolvement', 'MonthlyIncome',
#        'MonthlyRate', 'PercentSalaryHike', 'RelationshipSatisfaction',
#        'PerformanceRating', 'WorkLifeBalance', 'YearsInCurrentRole',
#        'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager',
#        'BusinessTravel_Non-Travel', 'BusinessTravel_Travel_Frequently',
#        'BusinessTravel_Travel_Rarely', 'Department_Human Resources',
#        'Department_Research & Development', 'Department_Sales',
#        'EducationField_Human Resources', 'EducationField_Life Sciences',
#        'EducationField_Marketing', 'EducationField_Medical',
#        'EducationField_Other', 'EducationField_Technical Degree',
#        'Gender_Female', 'Gender_Male', 'JobRole_Healthcare Representative',
#        'JobRole_Human Resources', 'JobRole_Laboratory Technician',
#        'JobRole_Manager', 'JobRole_Manufacturing Director',
# ...

# %%
feature.head(1)
# Out:
#    Age  Attrition  DistanceFromHome  Education  EnvironmentSatisfaction  \
# 0   41          1                 1          2                        2
#
#    JobInvolvement  MonthlyIncome  MonthlyRate  PercentSalaryHike  \
# 0               3           5993        19479                 11
#
#    RelationshipSatisfaction  ...  JobRole_Manufacturing Director  \
# 0                         1  ...                               0
#
#    JobRole_Research Director  JobRole_Research Scientist  \
# 0                          0                           0
#
#    JobRole_Sales Executive  JobRole_Sales Representative  \
# 0                        1                             0
#
#    MaritalStatus_Divorced  MaritalStatus_Married  MaritalStatus_Single  \
# 0                       0                      0                     1
#
#    OverTime  Attrition
# 0         1          1
#
# [1 rows x 44 columns]

# %%
import numpy as np
import pandas as pd
import joblib

# Load encoders and model
ohe_for_job_sat = joblib.load(r'..\Models\onehotforjobsat.pkl')
label_for_job_sat = joblib.load(r'..\Models\labelforjobsat.pkl')
# rfc = joblib.load(r'..\Models\rfc.pkl')  # Assuming this is the trained model

# Collect numerical inputs
age = int(input("Enter Age: "))
DistanceFromHome = int(input("Enter Distance from Home: "))
Education = int(input("Enter Education Level: "))
MonthlyIncome = int(input("Enter Monthly Income: "))
MonthlyRate = int(input("Enter Monthly Rate: "))
PercentSalaryHike = int(input("Enter Percent Salary Hike: "))
RelationshipSatisfaction = int(input("Enter Relationship Satisfaction: "))
PerformanceRating = int(input("Enter Performance Rating: "))
WorkLifeBalance = int(input("Enter Work-Life Balance: "))
YearsInCurrentRole = int(input("Enter Years in Current Role: "))
YearsAtCompany = int(input("Enter Years at Company: "))
YearsSinceLastPromotion = int(input("Enter Years Since Last Promotion: "))
YearsWithCurrManager = int(input("Enter Years with Current Manager: "))
NumCompaniesWorked = int(input("Enter Number of Companies Worked: "))
EnvironmentSatisfaction = int(input("Enter Environment Satisfaction: "))
JobInvolvement = int(input("Enter Job Involvement: "))

overtime = input("Enter Overtime (Yes/No): ").title()
le_ot = label_for_job_sat.transform(np.array([overtime]).reshape(1, -1)).flatten()[0]  # Label encoding

attrition = input("Enter Attrition (Yes/No): ").title()
le_attrition = label_for_job_sat.transform(np.array([attrition]).reshape(1, -1)).flatten()[0]  # Label encoding

# Collect categorical inputs
department = input("Enter Department: ").title()
marital_status = input("Enter Marital Status: ").title()
job_role = input("Enter Job Role: ").title()
gender = input("Enter Gender (Male/Female): ").title()
business_travel = input("Enter Business Travel (Non-Travel/Travel Frequently/Travel Rarely): ").title()
education_field = input("Enter Education Field: ").title()

# Create DataFrame for one-hot encoding
user_data = pd.DataFrame([{
    'BusinessTravel': business_travel,
    'Department': department,
    'EducationField': education_field,
    'Gender': gender,
    'JobRole': job_role,
    'MaritalStatus': marital_status
}])
encoded_user_input = ohe_for_job_sat.transform(user_data)

# Convert numerical inputs to a NumPy array
num_inputs = np.array([
    age, le_attrition, DistanceFromHome, Education, EnvironmentSatisfaction, JobInvolvement, 
    MonthlyIncome, MonthlyRate, PercentSalaryHike, RelationshipSatisfaction, PerformanceRating,
    WorkLifeBalance, YearsInCurrentRole, YearsAtCompany, YearsSinceLastPromotion,
    YearsWithCurrManager, le_ot, NumCompaniesWorked
]).reshape(1, -1)

# Concatenate numerical and categorical features
combined_input = np.concatenate([num_inputs, encoded_user_input], axis=1)

# Make prediction
prediction = rfc.predict(combined_input)

print("Predicted Output:", prediction)
# Out:
# d:\Projects\Employee-Attrition-Analysis-and-Prediction\venv\Lib\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# d:\Projects\Employee-Attrition-Analysis-and-Prediction\venv\Lib\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# Predicted Output: [2]
# d:\Projects\Employee-Attrition-Analysis-and-Prediction\venv\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
joblib.dump(rfc,r'..\Models\randomforestforjobsatisfcation.pkl')
# Out:
# ['..\\Models\\randomforestforjobsatisfcation.pkl']

# %%
import numpy as np
import pandas as pd
import joblib

# Load encoders and model
ohe_for_job_sat = joblib.load(r'..\Models\onehotforjobsat.pkl')
label_for_job_sat = joblib.load(r'..\Models\labelforjobsat.pkl')
# rfc = joblib.load(r'..\Models\rfc.pkl')  # Assuming this is the trained model

# Collect numerical inputs
age = int(input("Enter Age: "))
DistanceFromHome = int(input("Enter Distance from Home: "))
Education = int(input("Enter Education Level: "))
MonthlyIncome = int(input("Enter Monthly Income: "))
MonthlyRate = int(input("Enter Monthly Rate: "))
PercentSalaryHike = int(input("Enter Percent Salary Hike: "))
RelationshipSatisfaction = int(input("Enter Relationship Satisfaction: "))
PerformanceRating = int(input("Enter Performance Rating: "))
WorkLifeBalance = int(input("Enter Work-Life Balance: "))
YearsInCurrentRole = int(input("Enter Years in Current Role: "))
YearsAtCompany = int(input("Enter Years at Company: "))
YearsSinceLastPromotion = int(input("Enter Years Since Last Promotion: "))
YearsWithCurrManager = int(input("Enter Years with Current Manager: "))
NumCompaniesWorked = int(input("Enter Number of Companies Worked: "))
EnvironmentSatisfaction = int(input("Enter Environment Satisfaction: "))
JobInvolvement = int(input("Enter Job Involvement: "))

overtime = input("Enter Overtime (Yes/No): ").title()
le_ot = label_for_job_sat.transform(np.array([overtime]).reshape(1, -1)).flatten()[0]  # Label encoding

attrition = input("Enter Attrition (Yes/No): ").title()
le_attrition = label_for_job_sat.transform(np.array([attrition]).reshape(1, -1)).flatten()[0]  # Label encoding

# Collect categorical inputs
department = input("Enter Department: ").title()
marital_status = input("Enter Marital Status: ").title()
job_role = input("Enter Job Role: ").title()
gender = input("Enter Gender (Male/Female): ").title()
business_travel = input("Enter Business Travel (Non-Travel/Travel Frequently/Travel Rarely): ").title()
education_field = input("Enter Education Field: ").title()

# Create DataFrame for one-hot encoding
user_data = pd.DataFrame([{
    'BusinessTravel': business_travel,
    'Department': department,
    'EducationField': education_field,
    'Gender': gender,
    'JobRole': job_role,
    'MaritalStatus': marital_status
}])
encoded_user_input = ohe_for_job_sat.transform(user_data)

# Convert numerical inputs to a NumPy array
num_inputs = np.array([
    age, le_attrition, DistanceFromHome, Education, EnvironmentSatisfaction, JobInvolvement, 
    MonthlyIncome, MonthlyRate, PercentSalaryHike, RelationshipSatisfaction, PerformanceRating,
    WorkLifeBalance, YearsInCurrentRole, YearsAtCompany, YearsSinceLastPromotion,
    YearsWithCurrManager, le_ot, NumCompaniesWorked
]).reshape(1, -1)

# Concatenate numerical and categorical features
combined_input = np.concatenate([num_inputs, encoded_user_input], axis=1)

# Make prediction
prediction = rfc.predict(combined_input)

print("Predicted Output:", prediction)
# Out:
# d:\Projects\Employee-Attrition-Analysis-and-Prediction\venv\Lib\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# d:\Projects\Employee-Attrition-Analysis-and-Prediction\venv\Lib\site-packages\sklearn\preprocessing\_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[98], line 51
#      42 # Create DataFrame for one-hot encoding
#      43 user_data = pd.DataFrame([{
#      44     'BusinessTravel': business_travel,
# ...

# %%
rfc.feature_names_in_
# Out:
# array(['Age', 'Attrition', 'DistanceFromHome', 'Education',
#        'EnvironmentSatisfaction', 'JobInvolvement', 'MonthlyIncome',
#        'MonthlyRate', 'PercentSalaryHike', 'RelationshipSatisfaction',
#        'PerformanceRating', 'WorkLifeBalance', 'YearsInCurrentRole',
#        'YearsAtCompany', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'BusinessTravel_Non-Travel',
#        'BusinessTravel_Travel_Frequently', 'BusinessTravel_Travel_Rarely',
#        'Department_Human Resources', 'Department_Research & Development',
#        'Department_Sales', 'EducationField_Human Resources',
#        'EducationField_Life Sciences', 'EducationField_Marketing',
#        'EducationField_Medical', 'EducationField_Other',
#        'EducationField_Technical Degree', 'Gender_Female', 'Gender_Male',
#        'JobRole_Healthcare Representative', 'JobRole_Human Resources',
#        'JobRole_Laboratory Technician', 'JobRole_Manager',
# ...
